# %%
**Bienvenida**

# %%
a = 12*10

# %% [markdown]
# "lenguaje de programación orientado a objetos"

# %%
a
# Out:
# 120

# %%
type(a) #estructura de objeto creada
# Out:
# int

# %%
from IPython.display import Image
# %matplotlib inline

# %%
Image(filename='D:/Python/1. Nivel I/1/imagenes/01_00.png', width=400)

# %% [markdown]
# - **Coeficiente de Gini** Para el nodo $t$ y en cn $J$ clases
# $$i_G(t)=\sum^J_{j=1}p(j|t)[1-p(j|t)]$$
# $$= 1 - \sum^J_{j=1}p(j|t)^2$$
# <br>
#
# - **Entropía** Para el nodo $t$ y con $J$ clases
# $$i_e(t)=-\sum^J_{j=1}p(j|t)log[p(j|t)]$$

# %% [markdown]
# **Sentencia import**

# %%
import sklearn #funciones para tareas de preprocesamiento, reducción de dimensionalidad
#tareas de modelado de datos.

# %%
#una vez instala una librería nosotros la llamamos para su uso con la sentencia import
#las librerías se instalan una vez

# %%
import os #contiene funciones para consultar y establecer directorio de trabajo
import seaborn as sns #funciones para realizar gráficas

# %%
pip install imbalanced-learn

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
import pandas as pd

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import math as m

# %%
m.sqrt(144)
# Out:
# 12.0

# %%
import os

# %%
os.getcwd()#consultqmos el directorio de trabajo
# Out:
# 'C:\\Users\\SOCIAL DATA'

# %%
import model_evaluation_utils as meu

# %%
meu.train_predict_model
# Out:
# <function model_evaluation_utils.train_predict_model(classifier, train_features, train_labels, test_features, test_labels)>

# %%
#¿Cómo cambiamos el directorio de trabajo?
os.chdir("C:/Users/SOCIAL DATA/Desktop/scorecard")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\SOCIAL DATA\\Desktop\\scorecard'

# %%
pip install -U scikit-learn

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.10.0
# anaconda-project                   0.8.3
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asn1crypto                         1.4.0
# astroid                            2.4.2
# astropy                            4.0.2
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              20.3.0
# autopep8                           1.5.4
# Babel                              2.8.1
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.1
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# ...

# %% [markdown]
# **Sentencias de programación en python**

# %% [markdown]
# **def, if, else**

# %%
def resultado(x):
    if x<=10.4:
        salida = "desaprobado"
    else:
        salida = "aprobado"
    return salida

# %%
resultado(x=10.5)
# Out:
# 'aprobado'
